# %% [markdown]
# # **Descrubiendo el Poder de la Analítica**
# ## **Día 1**
#
# ### Meta: *Desarrollar un entendimiento intuitivo de procesar y analizar datos.*
# 1. Establecer un entendimiento básico de las herramientas y conceptos analíticos.
#     - Intro to programming, anatomy of terminal, github codespaces, jupyter
#
# 2. Distinguir cada paquete de Python y sus usos.
#     - Matplotlib, pandas, astropy, numpy, etc.
#
# 3. Discutir las importancias y relevancia de analizar datos en STEM.
#     - Practical applications of Data Analysis throughout STEM (Stats, Radio Astro, etc.)

# %%
import numpy as np
array_1d = np.array([1, 2, 3, 4, 5])
array_2d = np.array([[1, 2, 3], [4, 5, 6]])

# %%
print(array_1d)
# Out:
# [1 2 3 4 5]

# %%
# For plots inline in notebook
# %matplotlib inline 

# Import matplotlib
import matplotlib.pyplot as plt

# we will also need numpy
import numpy as np

# %%
# Setup X and Y values
x = np.linspace(0,25, 20)
y = np.sqrt(x)

# Create plot
plt.xlabel('This is X label')
plt.ylabel('This is Y label')
print(x)
print(y)
plt.plot(x,y);
# Out:
# [ 0.          1.31578947  2.63157895  3.94736842  5.26315789  6.57894737
#   7.89473684  9.21052632 10.52631579 11.84210526 13.15789474 14.47368421
#  15.78947368 17.10526316 18.42105263 19.73684211 21.05263158 22.36842105
#  23.68421053 25.        ]
# [0.         1.14707867 1.62221421 1.98679854 2.29415734 2.56494588
#  2.80975743 3.03488489 3.24442842 3.44123601 3.62738125 3.80442955
#  3.97359707 4.13585096 4.29197538 4.44261658 4.58831468 4.72952651
#  4.86664263 5.        ]
